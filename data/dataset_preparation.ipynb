# %%
# !wget https://raw.githubusercontent.com/BunnyNoBugs/hse-headlines-project/main/data/CorpusOfNewsHeadlines_new-Rus_FINAL.csv
# Out:
# --2023-03-16 15:40:32--  https://raw.githubusercontent.com/BunnyNoBugs/hse-headlines-project/main/data/CorpusOfNewsHeadlines_new-Rus_FINAL.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 980205 (957K) [text/plain]
# Saving to: ‘CorpusOfNewsHeadlines_new-Rus_FINAL.csv’
#
# CorpusOfNewsHeadlin 100%[===================>] 957.23K  --.-KB/s    in 0.05s
#
# 2023-03-16 15:40:32 (19.0 MB/s) - ‘CorpusOfNewsHeadlines_new-Rus_FINAL.csv’ saved [980205/980205]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('CorpusOfNewsHeadlines_new-Rus_FINAL.csv')
data.head()
# Out:
#                                             Headline        Date    Source  \
# 0  Разоблачитель российского допинга взялся за бр...  30.06.2018  lenta.ru
# 1  Главный тренер сборной Испании признал опаснос...  30.06.2018  lenta.ru
# 2  Дзюба признался в готовности встать на ворота ...  30.06.2018  lenta.ru
# 3  Макаревич пригрозил силовикам адом за преследо...  30.06.2018  lenta.ru
# 4           Власти объяснили введение платы за дождь  30.06.2018  lenta.ru
#
#                                         Link        Broad Topic       Type  \
# 0  https://lenta.ru/news/2018/06/30/zeppelt/             Sports     Honest
# 1  https://lenta.ru/news/2018/06/30/dangers/             Sports     Honest
# 2   https://lenta.ru/news/2018/06/30/dzyuba/             Sports  Clickbait
# 3     https://lenta.ru/news/2018/06/30/hell/    Politics, Stars  Clickbait
# 4     https://lenta.ru/news/2018/06/30/rain/  Urban development  Clickbait
#
#                                  Manipulative Device  \
# 0                                          Assertion
# 1                                          Assertion
# 2                          False actuality inference
# 3  False referentiality inference, Other inferenc...
# 4  False actuality inference, False referentialit...
#
#                                 Html-marked Headline  \
# 0  Разоблачитель российского допинга взялся за бр...
# 1  Главный тренер сборной Испании <trigger><ev:po...
# 2  Дзюба <trigger><ev:neg>признался</ev:neg><trig...
# 3  Макаревич <homonymy:sem>пригрозил силовикам <e...
# 4  Власти <trigger>объяснили</trigger> <trigger>в...
#
#                                              Summary
# 0  Хайо Зеппельт, расследоваший применения допинг...
# 1        Тренер считает Россию серьёзным соперником.
# 2  Дзюба сказал, что встанет на ворота только в с...
# 3  Музыкант сказал: "Ребят, ну не позорьтесь вы. ...
# 4  Власти Кунгура объяснили, что налога за дождь ...

# %%
dataset = data[['Headline', 'Type', 'Manipulative Device']]
dataset.head()
# Out:
#                                             Headline       Type  \
# 0  Разоблачитель российского допинга взялся за бр...     Honest
# 1  Главный тренер сборной Испании признал опаснос...     Honest
# 2  Дзюба признался в готовности встать на ворота ...  Clickbait
# 3  Макаревич пригрозил силовикам адом за преследо...  Clickbait
# 4           Власти объяснили введение платы за дождь  Clickbait
#
#                                  Manipulative Device
# 0                                          Assertion
# 1                                          Assertion
# 2                          False actuality inference
# 3  False referentiality inference, Other inferenc...
# 4  False actuality inference, False referentialit...

# %%
train_df, test_df = train_test_split(dataset, test_size=0.2, random_state=42)

# %%
train_df.to_csv('train.csv', index=False)
test_df.to_csv('test.csv', index=False)
